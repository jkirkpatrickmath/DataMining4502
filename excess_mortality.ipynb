# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import scipy.stats as stats
import statsmodels.formula.api as smf

# %%
hmd = pd.read_csv("selected_hmd", parse_dates = ["date"])

# %%
hmd['years_relative'] = hmd['date'].dt.year - 2020

# %%
country_codes = ['AUS', 'AUT', 'BEL', 'BGR', 'HRV', 'CHL', 'CZE', 'DNK', 'GBR', 'EST',
 'FIN', 'FRA', 'DEU', 'GRC', 'HUN', 'ISL', 'ISR', 'ITA', 'LVA', 'LTU', 'LUX', 'NLD',
  'NZL', 'NOR', 'POL', 'PRT', 'KOR', 'RUS', 'SVN', 'SVK', 'ESP', 'CHE', 'SWE', 'TWN', 'USA']

#for country in country_codes:
#    for week_num in range(1,53):
#        training_set = hmd[(hmd.country == country) & (hmd.years_relative < 0) & (hmd.week == week_num)]
#        model =  smf.ols(formula='mov_avg~years_relative', data=training_set).fit()
#        hmd['pred_deaths'] = model.predict(hmd[(hmd.country == country) & (hmd.week == week_num)])

for country in country_codes:
  for i in range(1, 53):
    training_set = hmd[(hmd.country == country) & (hmd.years_relative < 0) & (hmd.week == i)]
    model =  smf.ols(formula='mov_avg~years_relative', data=training_set).fit()
    hmd.loc[(hmd.country == country) & (hmd.week == i), 'pred_deaths'] = model.predict(hmd[(hmd.country == country) & (hmd.week == i)])

# %%
hmd
# Out:
#        Unnamed: 0.1       date  Unnamed: 0 country  week  year  DTotal  \
# 0             10501 1990-01-07       10501     FIN     1  1990  1146.0
# 1             10533 1990-01-14       10533     FIN     2  1990  1139.0
# 2             10565 1990-01-21       10565     FIN     3  1990  1185.0
# 3             10597 1990-01-28       10597     FIN     4  1990  1164.0
# 4             10629 1990-02-04       10629     FIN     5  1990  1103.0
# ...             ...        ...         ...     ...   ...   ...     ...
# 35415         20609 2022-01-30       20609     LTU     4  2022   917.0
# 35416         13433 2022-02-06       13433     GBR     5  2022  1610.0
# 35417          7491 2022-02-06        7491     DNK     5  2022  1193.0
# 35418         24108 2022-02-06       24108     NLD     5  2022  3450.0
# 35419          9462 2022-02-06        9462     EST     5  2022   373.0
#
#             mov_avg  years_relative   pred_deaths
# 0       1146.000000             -30    993.782488
# 1       1142.500000             -30   1009.888018
# 2       1156.666667             -30   1020.113159
# 3       1158.500000             -30   1024.963902
# 4       1147.400000             -30   1022.074409
# ...             ...             ...           ...
# 35415    962.000000               2    851.896321
# 35416  11961.571429               2  17897.621294
# 35417   1236.428571               2   1067.978022
# 35418   3384.285714               2   3112.960176
# 35419    370.142857               2    291.146316
#
# [35420 rows x 10 columns]
