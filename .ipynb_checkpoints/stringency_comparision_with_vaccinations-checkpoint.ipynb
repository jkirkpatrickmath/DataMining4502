# %%
valid_codes = '''AUS,AUT,BEL,BGR,HRV,CHL,CZE,DNK,GBR,EST,FIN,FRA,DEU,GRC,HUN,ISL,ISR,ITA,LVA,LTU,LUX,NLD,NZL,NOR,POL,PRT,KOR,RUS,SVN,SVK,ESP,CHE,SWE,TWN,USA'''.split(",")

# %%
#these are the countries we have ex_mort data for from country codes text file
#thank you Alex
print(valid_codes)
# Out:
# ['AUS', 'AUT', 'BEL', 'BGR', 'HRV', 'CHL', 'CZE', 'DNK', 'GBR', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HUN', 'ISL', 'ISR', 'ITA', 'LVA', 'LTU', 'LUX', 'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'KOR', 'RUS', 'SVN', 'SVK', 'ESP', 'CHE', 'SWE', 'TWN', 'USA']

# %%
import pandas as pd
import numpy as np
ex_mort = pd.read_csv("clean_combined.csv")
safety = pd.read_csv("covid-stringency-index.csv")
#only use countries that we have ex_mort data for
safety = safety[safety["Code"].isin(valid_codes)]
#only use weeks from the pandemic
ex_mort = ex_mort[ex_mort["years_relative"] >=0]


#convert to datetime to grab week number and year
safety["Day"] =  pd.to_datetime(safety["Day"])

# %%
safety["week"] = safety["Day"].dt.week
safety['year'] = safety["Day"].dt.year

# %%
si_df = safety.groupby(["Code", "week", "year"])["stringency_index"].mean().reset_index()
si_df = si_df.rename(columns={"Code": "country"})
si_df.head(10)
# Out:
#   country  week  year  stringency_index
# 0     AUS     1  2021         70.830000
# 1     AUS     1  2022         43.451429
# 2     AUS     2  2021         55.090000
# 3     AUS     2  2022         44.244286
# 4     AUS     3  2021         55.090000
# 5     AUS     3  2022         64.221429
# 6     AUS     4  2020          1.853333
# 7     AUS     4  2021         57.338571
# 8     AUS     4  2022         64.680000
# 9     AUS     5  2020          7.940000

# %%
#put the stringency index averages per week into the rest of the data
df = pd.merge(ex_mort, si_df)
df.head(10)
# Out:
#          date country  week  year  DTotal      mov_avg  years_relative  \
# 0  2020-02-02     CHL     4  2020  1964.0  2006.714286               0
# 1  2020-02-02     SWE     4  2020  1730.0  1791.000000               0
# 2  2020-02-02     ESP     4  2020  9954.0  9006.428571               0
# 3  2020-02-02     DNK     4  2020  1033.0  1079.714286               0
# 4  2020-02-02     LVA     4  2020   555.0   572.000000               0
# 5  2020-02-02     GRC     4  2020  2774.0  2668.285714               0
# 6  2020-02-02     BEL     4  2020  2204.0  2263.142857               0
# 7  2020-02-02     LUX     4  2020    86.0    84.571429               0
# 8  2020-02-02     KOR     4  2020  6490.0  6244.000000               0
# 9  2020-02-02     HUN     4  2020  2723.0  2580.000000               0
#
#    pred_deaths  excess_mortality  em_per_capita  ...  new_cases  total_deaths  \
# 0  1875.178571        131.535714   6.846410e-06  ...        NaN           NaN
# 1  1861.609774        -70.609774  -6.949672e-06  ...        1.0           NaN
# 2  9470.538910       -464.110338  -8.516927e-05  ...        NaN           NaN
# 3  1063.016484         16.697802   1.990192e-07  ...       10.0           NaN
# 4   555.143985         16.856015   1.814230e-06  ...        NaN           NaN
# 5  2680.928571        -12.642857  -1.853598e-07  ...        2.0           NaN
# 6  2273.806015        -10.663158  -9.166826e-07  ...        NaN           NaN
# 7    84.822932         -0.251504  -4.902112e-09  ...       12.0           NaN
# 8  6382.580952       -138.580952  -2.703333e-05  ...        NaN           NaN
# 9  2673.120301        -93.120301  -8.979131e-06  ...        0.0           NaN
#
#    new_deaths  total_cases_per_million  hosp_patients  population  \
# 0         NaN                      NaN            NaN         NaN
# 1         0.0                    0.098            NaN  10160159.0
# 2         NaN                      NaN            NaN         NaN
# 3         0.0                    0.012            NaN  83900471.0
# 4         NaN                      NaN            NaN         NaN
# 5         0.0                    0.029            NaN  68207114.0
# 6         NaN                      NaN            NaN         NaN
# 7         0.0                    0.078            NaN  51305184.0
# 8         NaN                      NaN            NaN         NaN
# 9         0.0                      NaN            NaN         NaN
#
#    mov_avg_cases  new_cases_per_capita  normalized_cases  stringency_index
# 0            NaN                   NaN               NaN               0.0
# 1            1.0          9.842366e-08      3.057224e-06               0.0
# 2            NaN                   NaN               NaN               0.0
# 3           10.0          1.191888e-07      3.702230e-06               0.0
# 4            NaN                   NaN               NaN               0.0
# 5            2.0          2.932245e-08      9.108106e-07               0.0
# 6            NaN                   NaN               NaN               0.0
# 7            7.0          1.364385e-07      4.238035e-06               0.0
# 8            NaN                   NaN               NaN               0.0
# 9            0.0                   NaN               NaN               0.0
#
# [10 rows x 24 columns]

# %%
#loading vaccination data, converting date to week/year
owidVac = pd.read_csv("vaccinations.csv")
owidVac = owidVac[owidVac["iso_code"].isin(valid_codes)]

owidVac["date"] = pd.to_datetime(owidVac["date"])
owidVac["week"] = owidVac["date"].dt.week
owidVac['year'] = owidVac["date"].dt.year

# %%
#sort vaccination data, prepare for merge
vc = owidVac.groupby(["iso_code", "week", "year", "people_vaccinated", "people_fully_vaccinated"])["total_vaccinations"].max().reset_index()
vc = vc.rename(columns={"iso_code": "country"})
vc.head(10)
# Out:
#   country  week  year  people_vaccinated  people_fully_vaccinated  \
# 0     AUS     1  2022         20463839.0               19782523.0
# 1     AUS     1  2022         20475452.0               19806589.0
# 2     AUS     1  2022         20488662.0               19832376.0
# 3     AUS     1  2022         20503096.0               19857649.0
# 4     AUS     1  2022         20516623.0               19882365.0
# 5     AUS     1  2022         20524868.0               19896355.0
# 6     AUS     1  2022         20529932.0               19904821.0
# 7     AUS     2  2022         20578901.0               19928352.0
# 8     AUS     2  2022         20644440.0               19946441.0
# 9     AUS     2  2022         20714403.0               19967401.0
#
#    total_vaccinations
# 0          42812691.0
# 1          43024593.0
# 2          43286155.0
# 3          43558448.0
# 4          43823668.0
# 5          43987111.0
# 6          44086608.0
# 7          44374463.0
# 8          44700720.0
# 9          45045755.0

# %%
#merge vaccination data into dataset
df = pd.merge(df, vc)

df["percent_vaccinated"] = df["people_fully_vaccinated"]/df['population']
print(df["percent_vaccinated"].isna().sum())
#drop 133 na in percent vacc
df = df.dropna(subset = ['percent_vaccinated'])
print(df["percent_vaccinated"].isna().sum())
df.head(10)
# Out:
# 0
# 0
#          date country  week  year   DTotal       mov_avg  years_relative  \
# 0  2020-12-20     USA    50  2020  81952.0  71991.142857               0
# 1  2020-12-27     ISR    51  2020   1007.0    925.571429               0
# 2  2020-12-27     ISR    51  2020   1007.0    925.571429               0
# 3  2020-12-27     USA    51  2020  82864.0  74772.857143               0
# 4  2020-12-27     USA    51  2020  82864.0  74772.857143               0
# 5  2020-12-27     USA    51  2020  82864.0  74772.857143               0
# 6  2020-12-27     USA    51  2020  82864.0  74772.857143               0
# 7  2020-12-27     USA    51  2020  82864.0  74772.857143               0
# 8  2020-12-27     USA    51  2020  82864.0  74772.857143               0
# 9  2020-12-27     USA    51  2020  82864.0  74772.857143               0
#
#     pred_deaths  excess_mortality  em_per_capita  ...  hosp_patients  \
# 0  57378.114286      14613.028571       0.000044  ...       109689.0
# 1    888.566165         37.005263       0.000004  ...         7097.0
# 2    888.566165         37.005263       0.000004  ...         7097.0
# 3  57984.942857      16787.914286       0.000050  ...       114648.0
# 4  57984.942857      16787.914286       0.000050  ...       114648.0
# 5  57984.942857      16787.914286       0.000050  ...       114648.0
# 6  57984.942857      16787.914286       0.000050  ...       114648.0
# 7  57984.942857      16787.914286       0.000050  ...       114648.0
# 8  57984.942857      16787.914286       0.000050  ...       114648.0
# 9  57984.942857      16787.914286       0.000050  ...       114648.0
#
#     population  mov_avg_cases  new_cases_per_capita  normalized_cases  \
# 0  332915074.0   1.246826e+06              0.003745          0.116332
# 1    9634162.0   2.949200e+04              0.003061          0.095086
# 2    9634162.0   2.949200e+04              0.003061          0.095086
# 3  332915074.0   1.320415e+06              0.003966          0.123198
# 4  332915074.0   1.320415e+06              0.003966          0.123198
# 5  332915074.0   1.320415e+06              0.003966          0.123198
# 6  332915074.0   1.320415e+06              0.003966          0.123198
# 7  332915074.0   1.320415e+06              0.003966          0.123198
# 8  332915074.0   1.320415e+06              0.003966          0.123198
# 9  332915074.0   1.320415e+06              0.003966          0.123198
#
#    stringency_index  people_vaccinated  people_fully_vaccinated  \
# 0         71.760000            26321.0                   6449.0
# 1         70.505714               68.0                      4.0
# 2         70.505714             7458.0                      4.0
# 3         71.760000            30754.0                   6575.0
# 4         71.760000            76563.0                   6839.0
# 5         71.760000           230719.0                   7292.0
# 6         71.760000           496429.0                   8049.0
# 7         71.760000           904477.0                   9252.0
# 8         71.760000          1082644.0                  10322.0
# 9         71.760000          1186226.0                  11044.0
#
#    total_vaccinations  percent_vaccinated
# 0             31762.0        1.937131e-05
# 1                72.0        4.151892e-07
# 2              7462.0        4.151892e-07
# 3             36356.0        1.974978e-05
# 4             84328.0        2.054278e-05
# 5            243701.0        2.190348e-05
# 6            516306.0        2.417734e-05
# 7            932797.0        2.779087e-05
# 8           1114834.0        3.100490e-05
# 9           1220381.0        3.317363e-05
#
# [10 rows x 28 columns]

# %%
import seaborn
import matplotlib.pyplot as plt
df.plot.scatter("stringency_index", "em_per_capita")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
seaborn.set(style='ticks')
seaborn.relplot(data=df, x='stringency_index', y='em_per_capita', hue='year',  aspect=1.61)
plt.show()

# %%
year2 = df[df["year"] == 2021]

# %%
seaborn.relplot(data=year2, x='stringency_index', y='em_per_capita', aspect=1.61)
plt.show()

# %%
pd.plotting.scatter_matrix(df[["year", "em_per_capita", "normalized_cases", "stringency_index"]])
plt.show()

# %%
seaborn.relplot(data=year2, x='stringency_index', y='normalized_cases', aspect=1.61)
plt.show()

# %%
from sklearn import linear_model
df = df[df['normalized_cases'].notna()]
reg = linear_model.LinearRegression()
testx = df[["stringency_index"]]
testy = df["normalized_cases"]
colors = df["country"]
reg.fit(testx, testy)
reg.score(testx, testy)
y_pred = reg.predict(testx)
seaborn.relplot(data=df, x='stringency_index', y='normalized_cases', hue='country',  aspect=1.61)
plt.plot(testx, y_pred, color ='k')
  
plt.show()

# %%
df = df[df["country"] != "ITA"]
testx = df[["stringency_index"]]
testy = df["percent_vaccinated"]
print(df['percent_vaccinated'].isna().sum())
reg.fit(testx, testy)
reg.score(testx, testy)
y_pred = reg.predict(testx)
seaborn.relplot(data=df, x='stringency_index', y='percent_vaccinated', hue='country',  aspect=1.61)
plt.plot(testx, y_pred, color ='k')
plt.xlabel("stringency_index")
plt.ylabel("percent_vaccinated")
  
plt.show()
# Out:
# 0

# %%
reg.score(testx, testy)
# Out:
# 0.014141202279716603

# %%
from sklearn.cluster import KMeans
y_pred = KMeans(n_clusters=2).fit_predict(testx)

plt.scatter(testx, testy, c=y_pred)

plt.show()

# %%
ridgereg = linear_model.Ridge(0.5)
ridgereg.fit(testx,testy)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
import datetime
ex_mort = pd.read_csv("clean_combined.csv")
safety = pd.read_csv("covid-stringency-index.csv")
#only use countries that we have ex_mort data for
safety = safety[safety["Code"].isin(valid_codes)]
#only use weeks from the pandemic
ex_mort = ex_mort[ex_mort["years_relative"] >=0]

for i in range(6):
    d = datetime.timedelta(days=i*7)
    #convert to datetime to grab week number and year
    safety["Day"] =  pd.to_datetime(safety["Day"])+d

    safety["week"] = safety["Day"].dt.week
    safety['year'] = safety["Day"].dt.year
    si_df = safety.groupby(["Code", "week", "year"])["stringency_index"].mean().reset_index()
    si_df = si_df.rename(columns={"Code": "country"})
    si_df.head(10)

    df = pd.merge(ex_mort, si_df)
    seaborn.relplot(data=df, x='stringency_index', y='em_per_capita', hue='year', aspect=1.61).set(title = "{} day offset".format(i*7))
    plt.show()
